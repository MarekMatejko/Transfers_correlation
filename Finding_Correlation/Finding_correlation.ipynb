# %%
# Load data from CSV files into DataFrames

import pandas as pd

df_merged_data = pd.read_csv('df_merged_data.csv')
df_merged_data
# Out:
#               Teams Places  Matches  Wins  Draws  Loses  Goals  Goals Diff  \
# 0          Man City    1         38    28      7      3  96:34          62
# 1           Arsenal    2         38    28      5      5  91:29          62
# 2         Liverpool    3         38    24     10      4  86:41          45
# 3       Aston Villa    4         38    20      8     10  76:61          15
# 4         Tottenham    5         38    20      6     12  74:61          13
# ..              ...    ...      ...   ...    ...    ...    ...         ...
# 395      Portsmouth   16         38    10      9     19  43:59         -16
# 396       West Brom   17         38     6     16     16  36:61         -25
# 397  Crystal Palace   18         38     7     12     19  41:62         -21
# 398         Norwich   19         38     7     12     19  42:77         -35
# 399     Southampton   20         38     6     14     18  45:66         -21
#
#      Points   Year        Spend      Balance
# 0        91  23/24  259600000.0 -133800000.0
# 1        89  23/24  235100000.0 -165900000.0
# 2        82  23/24  172000000.0 -111300000.0
# 3        68  23/24  111500000.0  -78950000.0
# 4        66  23/24  272100000.0 -151400000.0
# ..      ...    ...          ...          ...
# 395      39  04/05   10850000.0   -4250000.0
# 396      34  04/05   15850000.0  -13900000.0
# 397      33  04/05    5150000.0   -5050000.0
# 398      33  04/05    8530000.0   -8080000.0
# 399      32  04/05   12680000.0   -1180000.0
#
# [400 rows x 12 columns]

# %%
# Group by Year, sort by Spend descending, reset index, assign Spend_Rank
def assign_ranking(df):
    df = df.groupby('Year').apply(lambda x: x.sort_values(by='Spend', ascending=False)
                                          .reset_index(drop=True)
                                          .assign(Spend_Rank=lambda x: x.index + 1))
    return df.reset_index(drop=True)

# Apply the function to the entire DataFrame
df_merged_data = assign_ranking(df_merged_data)
df_merged_data
# Out:
#               Teams Places  Matches  Wins  Draws  Loses   Goals  Goals Diff  \
# 0           Chelsea    1         38    29      8      1   72:15          57
# 1           Man Utd    3         38    22     11      5   58:26          32
# 2         Liverpool    5         38    17      7     14   52:41          11
# 3         Tottenham    9         38    14     10     14   47:41           6
# 4         Newcastle   14         38    10     14     14   47:57         -10
# ..              ...    ...      ...   ...    ...    ...     ...         ...
# 395       Brentford   16         38    10      9     19   56:65          -9
# 396  Crystal Palace   10         38    13     10     15   57:58          -1
# 397       Sheff Utd   20         38     3      7     28  35:104         -69
# 398         Everton   15         38    13      9     16   40:51         -11
# 399           Luton   18         38     6      8     24   52:85         -33
#
#      Points   Year        Spend      Balance  Spend_Rank
# 0        95  04/05  162400000.0 -159100000.0           1
# 1        77  04/05   61250000.0  -51690000.0           2
# 2        58  04/05   58400000.0  -33830000.0           3
# 3        52  04/05   47130000.0  -36630000.0           4
# 4        44  04/05   29450000.0   -7180000.0           5
# ..      ...    ...          ...          ...         ...
# 395      39  23/24   72350000.0  -62100000.0          16
# 396      49  23/24   67800000.0  -67800000.0          17
# 397      16  23/24   66950000.0  -36050000.0          18
# 398      40  23/24   40500000.0   42300000.0          19
# 399      26  23/24   25920000.0  -25620000.0          20
#
# [400 rows x 13 columns]

# %%
# Calculate the correlation between Places and Spend_Rank for each year 
def calculate_correlation_with_lambda(df):
    correlations = df.groupby('Year').apply(
        lambda x: x[['Places', 'Spend_Rank']].astype(float)
        .corr().loc['Places', 'Spend_Rank']
    ).reset_index(name='Correlation')
    return correlations

# Apply the function to the entire DataFrame
correlations = calculate_correlation_with_lambda(df_merged_data)
correlations
# Out:
#      Year  Correlation
# 0   04/05     0.255639
# 1   05/06     0.615038
# 2   06/07     0.243609
# 3   07/08     0.419549
# 4   08/09     0.517293
# 5   09/10     0.556391
# 6   10/11     0.557895
# 7   11/12     0.362406
# 8   12/13     0.490226
# 9   13/14     0.574436
# 10  14/15     0.670677
# 11  15/16     0.067669
# 12  16/17     0.624060
# 13  17/18     0.601504
# 14  18/19     0.290226
# 15  19/20     0.320301
# 16  20/21     0.648120
# 17  21/22     0.651128
# 18  22/23     0.174436
# 19  23/24     0.768421
